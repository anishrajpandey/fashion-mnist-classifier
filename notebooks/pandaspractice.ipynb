# %% [markdown]
# # Introduction to Pandas
#
# Pandas is a powerful Python library for data manipulation and analysis. It provides data structures and functions needed to work with structured data seamlessly.
#
# ## Key Features
#
# - **DataFrames**: 2D labeled data structures with columns of potentially different types
# - **Series**: 1D labeled array capable of holding any data type
# - **Data Cleaning**: Tools for handling missing data and data transformations
# - **Data Analysis**: Built-in methods for aggregation, grouping, and statistical analysis
# - **Input/Output**: Read and write data from various file formats (CSV, Excel, SQL, etc.)
#
# ## Basic Concepts
#
# **DataFrame**: The primary data structure in pandas, similar to a table with rows and columns.
#
# **Series**: A one-dimensional array-like object that can hold any data type.
#
# **Index**: Labels for rows and columns that enable easy data access and manipulation.
#
# Pandas is built on top of NumPy and integrates well with other data science libraries like Matplotlib and Scikit-learn, making it essential for data science workflows.

# %%
import pandas as pd
s=pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df=pd.DataFrame({"names":["Anish", "Bansh"], "ages": [21,31]}, index=["a", "b"])
df
# Out:
#    names  ages
# a  Anish    21
# b  Bansh    31

# %%
df=pd.read_csv('../data/test.csv')
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df.describe()
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    object
#  2   First Name         100 non-null    object
#  3   Last Name          100 non-null    object
#  4   Company            100 non-null    object
#  5   City               100 non-null    object
#  6   Country            100 non-null    object
#  7   Phone 1            100 non-null    object
#  8   Phone 2            100 non-null    object
#  9   Email              100 non-null    object
#  10  Subscription Date  100 non-null    object
#  11  Website            100 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 9.5+ KB

# %%
# data selection
df[["Customer Id", "Email"]]
# Out:
#         Customer Id                           Email
# 0   DD37Cf93aecA6Dc        zunigavanessa@smith.info
# 1   1Ef7b82A4CAAD10                 vmata@colon.com
# 2   6F94879bDAfE5a6             beckycarr@hogan.com
# 3   5Cef8BFA16c5e3c     stanleyblackwell@benson.org
# 4   053d585Ab6b3159         colinalvarado@miles.net
# ..              ...                             ...
# 95  cb8E23e48d22Eae                hhart@jensen.com
# 96  CeD220bdAaCfaDf               vkemp@ferrell.com
# 97  28CDbC0dFe4b1Db                swagner@kane.org
# 98  c23d1D9EE8DEB0A  mccarthystephen@horn-green.biz
# 99  2354a0E336A91A1          colleen91@faulkner.biz
#
# [100 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Index                                         1
# Customer Id                     DD37Cf93aecA6Dc
# First Name                               Sheryl
# Last Name                                Baxter
# Company                         Rasmussen Group
# City                               East Leonard
# Country                                   Chile
# Phone 1                            229.077.5154
# Phone 2                        397.884.0519x718
# Email                  zunigavanessa@smith.info
# Subscription Date                    2020-08-24
# Website              http://www.stephenson.com/
# Name: 0, dtype: object

# %%
df.dropna()
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.fillna(0)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df.rename(columns={"Customer Id": "Id"}, inplace=True)

# %%
df
# Out:
#     Index               Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
df['Id'].astype(str)
# Out:
# 0     DD37Cf93aecA6Dc
# 1     1Ef7b82A4CAAD10
# 2     6F94879bDAfE5a6
# 3     5Cef8BFA16c5e3c
# 4     053d585Ab6b3159
#            ...
# 95    cb8E23e48d22Eae
# 96    CeD220bdAaCfaDf
# 97    28CDbC0dFe4b1Db
# 98    c23d1D9EE8DEB0A
# 99    2354a0E336A91A1
# Name: Id, Length: 100, dtype: object

# %%
type(df['Id'])
# Out:
# pandas.core.series.Series

# %%
len(df)
# Out:
# 100

# %%
df["City"]=df["City"].apply(lambda x: "Austin")

# %%
df.tail()
# Out:
#     Index               Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#       City          Country               Phone 1                 Phone 2  \
# 95  Austin           Guyana   (188)169-1674x58692    001-841-293-3519x614
# 96  Austin        Sri Lanka       +1-846-706-2218            605.413.3198
# 97  Austin  Solomon Islands  +1-753-067-8419x7170   +1-632-666-7507x92121
# 98  Austin            Aruba         (530)311-9786  001-869-452-0943x12424
# 99  Austin         Honduras         (753)813-6941            783.639.1472
#
#                              Email Subscription Date  \
# ...

# %%
df.to_pdf('../data/modified_test.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/t_/s0js4s493rl11zglcfk9vqjc0000gn/T/ipykernel_6623/3819986134.py in ?()
# ----> 1 df.to_pdf('../data/modified_test.pdf')
#
# ~/Code Playground/fashion_mnist_classifier/.venv/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_pdf'
